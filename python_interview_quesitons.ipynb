# %% [markdown]
# <a href="https://colab.research.google.com/github/mekusaha/dsa/blob/main/python_interview_quesitons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List
# Online Python compiler (interpreter) to run Python online.
# Write Python 3 code in this online editor and run it.


#Q: Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
'''
list1 = ["M", "na", "i", "Abhirup"]
list2 = ["y", "me", "s", "Kumar"]

x = [ i+""+j for i,j in zip(list1,list2)]
print(x, end=" ")
'''
#==========================================================================

#Q: Find whether one array is subset of Another array. Eg.
'''
X=[4,3,8,1]
Y=[11,4,3,7,1,8]

def check_subset(X,Y):
    for i in range(len(min(X,Y))):
        if X[i] not in Y:
            return False
    return True

print(check_subset(X,Y))
'''
#==========================================================================

#Q: Given a two Python lists. Write a program to iterate both lists simultaneously and display items from list1 in original order and items from list2 in reverse order.
'''
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]


x = [str(i)+" -> "+str(j) for i,j in zip(list1,list2[::-1])]
print(x)
'''
#==========================================================================

#Q: Write a program to find value 20 in a list, if its present replace it with 200. Only update the first occurance of a item
'''
list1 = [5,10,15,20,25,50,20]

for i,j in enumerate(list1):
    if j == 20:
        list1[i]=200
        break

print(list1)
'''
#==========================================================================

#Q: Remove duplicates from a list.
'''
list1 = [1,2,3,4,2,3,1,5,6,8,4,3,9]
print(set(list1))
'''
#==========================================================================

#Q: Show some SET operations.
'''
a = {1,2,3}
b = {3,4,5}
s = {1, 2, 3}

print(a|b) # Union of both
print(a&b) # Get common value
print(a-b) # Items left out in A after removing commons
print(a^b) # Symmetric difference

s.add(4)         # Add an element
s.remove(2)      # Remove element (raises error if not found)
s.discard(5)     # Remove element if present (no error)
s.clear()
'''
#==========================================================================

#Q: Find the Nth Largest Element in a List, Without sorting the list.
#list1 = [5,10,15,20,25,50,20]
'''
list1 = [5,10,1,4,9,8,11]
n = 3
s = set(list1)
print(s)

for i in range(n-1):
    s.remove(max(s))

print(max(s))
'''
#==========================================================================

#Q: Rotate a List left/right by K Steps, Given a list and an integer K, rotate the list to the right by K steps.
'''
k=2
list1 = [5,10,1,4,9,8,11]
sub_l1 = list1[:k]
sub_l2 = list1[k:]

sub_r1 = list1[:-k]
sub_r2 = list1[-k:]

print(sub_l2+sub_l1)
print(sub_r2+sub_r1)
'''
#==========================================================================

#Q: Flatten a Nested List, Given a list of lists, flatten it into a single list.
# Eg. flatten([[1, 2], [3, 4], [5]])  # Output: [1, 2, 3, 4, 5]
'''
x = [[1, 2], [3, 4], [5]]

def flatten(x):
    return [j for i in x for j in i]

print(flatten(x))
'''
#==========================================================================

#Q: Find Pairs with Given Sum, Return all unique pairs in a list that sum up to a specific value. (2 sum problem)
'''
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        seen = set()
        result = set()

        for i in nums:
            diff = target - i

            if diff in seen:
                result.add(tuple([i,diff]))
            seen.add(i)
        return result


sol = Solution()

x = [3,4,7,14,8,9,10]
sol.twoSum(x,12)
'''
#==========================================================================

#Q: Check if Two Lists Have Any Common Elements Use sets to efficiently check for intersection.
'''
set1 = {1,2,3,4,5}
set2 = {4,3,5,6,1}

print(set1&set2)
'''
#==========================================================================

#Q: Count Unique Elements in a List, Count how many unique elements exist in a list.
'''
set1 = {1,2,3,4,5,4,7,9,3,4,6,2,1,7,9,8,2}
print(len(set(set1)))
'''
#==========================================================================

#Q: Use Binary search to
# Out:
# 9
